# %%
pip install -U -q "google-generativeai>=0.7.2"

# %%
import google.generativeai as genai
from google.colab import userdata

GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
genai.configure(api_key=GOOGLE_API_KEY)

# %%
from google import genai
from google.genai import types

client = genai.Client(api_key=GOOGLE_API_KEY)

# %%
import pathlib
import textwrap

from IPython.display import display, Markdown

def to_markdown(text):
    text = text.replace('*', ' *')
    return Markdown(textwrap.indent(text, '> ', predicate = lambda _: True))

# %%
import PIL.Image
img=PIL.Image.open('image1.jpg')
img
model=genai.GenerativeModel('gemini-1.5-flash')
response=model.generate_content(["Write a short, engaging blog post based on this picture. It should inckude a description of the meal in the pjoto and talk about my journey meal prepping.", img], stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# > ## My Meal Prep Journey: From Chaos to Deliciousness!
# >
# > Let's be honest, meal prepping used to feel like a chore.  Images of perfectly portioned containers filled with vibrant food felt miles away from my reality.  My lunch usually involved a sad desk sandwich, or worse, a vending machine raid.  But then something clicked!
# >
# > The photo above showcases the fruits (or should I say,  *veggies *?) of my labor.  Those are two containers of teriyaki chicken and broccoli over fluffy white rice, with a side of colorful bell peppers. Each bite is packed with flavor and I’m ready for the week! The prep involved a big batch cooking session, but now my lunch is ready with no-fuss.
# >
# ...

# %%
response=model.generate_content(["Generate an accurate caption for this image", img])
print(response.text)
# Out:
# Here are a few caption options for the image:
#
# **Option 1 (Simple & Descriptive):**
#
# > Healthy and delicious meal prep!  Chicken and broccoli with rice.
#
#
# **Option 2 (More Engaging):**
#
# > Lunch goals!  These chicken and veggie bowls are packed with flavor and ready in minutes.  Perfect for busy weeknights. #mealprep #healthyfood #lunchideas #chickenandbroccoli
#
#
# **Option 3 (Focus on Convenience):**
#
# > Easy weeknight dinners made simple.  Grab-and-go meal prep containers filled with teriyaki chicken, rice, broccoli, and carrots. #mealprepsunday #easyrecipes #healthylifestyle
#
#
# **Option 4 (Question to Engage Audience):**
#
# > What's your favorite meal prep recipe?  These chicken and veggie bowls are definitely a top contender for us! #mealprepideas #healthymeals #foodie
#
#
# ...

# %%
from PIL import Image
image_path = "girl.jpg"
image = Image.open(image_path)
response=model.generate_content(["Descibe this image in detail.", image])
print(response.text)
# Out:
# Here's a description of the image:
#
# Close-up view of a woman with shoulder-length, curly brown hair.
#
#
# She is light-skinned and has a warm, friendly expression. Her makeup is subtle, and she's wearing a teal-colored three-quarter sleeve tunic or kurta. The tunic features a light gold, subtle print of what appears to be small floral or paisley-like designs. The neckline is a modest, rounded collar.
#
#
# The woman is gesturing with her right hand, pointing to her left side, suggesting she's directing attention to something off-camera. Her left arm is folded across her body, and her overall posture is relaxed and approachable. The background is a plain, bright white, keeping the focus solely on the woman.

# %%
response=model.generate_content(["What emotion can you detect ind the image?", image])
print(response.text)
# Out:
# The woman in the image appears to be expressing **confidence** or **assurance**.  Her pose, with her arm across her body and finger pointing, suggests she is presenting something or directing attention to something off-camera. Her smile further enhances this impression.

# %%
response=model.generate_content(["judge her", image])
print(response.text)
# Out:
# The woman in the image is pleasant-looking.  She appears friendly and approachable, with a warm smile.  Her clothing and styling suggest a casual, possibly slightly formal, setting. There is nothing to judge negatively about her appearance.

# %%
response=model.generate_content(["assume which place she is in", image])
print(response.text)
# Out:
# Based on the image, the woman appears to be in a photo studio or a space with a plain white background.  There are no other identifying features to suggest a specific location beyond that.

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x423>

# %%
response=model.generate_content(["Can you reimage it and make her sad", image])
print(response.text)
# Out:
# Here's a description of how to make the image portray sadness, keeping in mind that I can't actually *modify* the image:
#
#
# To evoke sadness, we'd need to alter the woman's expression and posture.  Instead of pointing, her arms could be folded across her chest, her shoulders slumped, and her head slightly bowed.  Her smile should be replaced with a downturned mouth and perhaps slightly teary eyes. The overall effect should communicate a sense of dejection or melancholic introspection.  The background could remain the same, but the lack of a smile against the plain white background would emphasize the sadness.

# %%
from PIL import Image
image_path = "hi.png"
image = Image.open(image_path)
response=model.generate_content(["Extract text from image.", image])
print(response.text)
# Out:
# Here's a transcription of the text from the word cloud image:
#
# soldiers burned yes took look austrian takes throne father horse others still battle
# position two face sonya kutuzov anything voice house
# oh pierre much go eyes though just first nothing like
# good day emperor put without now thought asked general right
# place hand french know life something one looked napoleon well understood
# behind people time chapter evidently natasha looking princessrostov must
# countess andrew natasha clear anna began army russian
# room man count order went prince suddenly knew feeling
# replied young another nicholas done see love moscow head old think
# smile long away come see whole everything back little even
# round heard always mary left felt boris saw officer going make door
# never way made words

# %%
from PIL import Image
image_path = "hello.png"
image = Image.open(image_path)
response=model.generate_content(["Extract text from image.", image])
print(response.text)
# Out:
# SCENE FROM "DAN'L DRUCE."
#
# ...
